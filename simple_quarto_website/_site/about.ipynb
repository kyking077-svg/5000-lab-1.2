# %% [raw]
# ---
# title: "About"
# ---

# %% [markdown]
# # Why I Love Stardew Valley
# As you can see by the following chart, my joy increases exponentially the longer I play Stardew Valley

# %% [markdown]
# #### The Chart

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt

# making some data to demonstrate
time_minutes = np.linspace(0, 50, 100)
joy = np.exp(0.1 * time_minutes)

# nice chart about joy and playing Stardew Valley
plt.figure(figsize=(8,5))
plt.plot(time_minutes, joy, color='green', linewidth=2)
plt.title("Joy vs Time Playing Stardew Valley")
plt.xlabel("Time Playing (minutes)")
plt.ylabel("Joy (counts of Whimsy)")
plt.grid(True)
plt.show()
